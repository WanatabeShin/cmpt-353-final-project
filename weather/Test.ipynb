# %%
import numpy as np
import pandas as pd
import glob

# %% [markdown]
# https://climate.weather.gc.ca/glossary_e.html#weather
# <br>
# Good weather means:
# <br>
# - Clear
# - Mainly clear
# - Mostly cloudy
# - Cloudy data

# %%
filename = "hourly_2014_2019/2019/en_climate_hourly_BC_1108395_01-2019_P1H.csv"
df = pd.read_csv(filename, index_col=None, header=0, parse_dates = ["Date/Time"])

#Get date time and weather status
filterDf = df[["Date/Time","Year", "Month", "Day", "Time", "Weather"]]
filterDf
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-04eb13efb553> in <module>
#       1 filename = "hourly_2014_2019/2019/en_climate_hourly_BC_1108395_01-2019_P1H.csv"
# ----> 2 df = pd.read_csv(filename, index_col=None, header=0, parse_dates = ["Date/Time"])
#       3
#       4 #Get date time and weather status
#       5 filterDf = df[["Date/Time","Year", "Month", "Day", "Time", "Weather"]]
#
# ~/.local/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~/.local/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/.local/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/.local/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~/.local/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'hourly_2014_2019/2019/en_climate_hourly_BC_1108395_01-2019_P1H.csv' does not exist: b'hourly_2014_2019/2019/en_climate_hourly_BC_1108395_01-2019_P1H.csv'

# %%
filterDf["Weather"].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-da6f42341865> in <module>
# ----> 1 filterDf["Weather"].unique()
#
# NameError: name 'filterDf' is not defined

# %%
#Add a column for Date only
filterDf["Date"] = filterDf['Date/Time'].apply(lambda x:x.date().strftime('%Y-%m-%d'))
filterDf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-459ca04d5bea> in <module>
#       1 #Add a column for Date only
# ----> 2 filterDf["Date"] = filterDf['Date/Time'].apply(lambda x:x.date().strftime('%Y-%m-%d'))
#       3 filterDf
#
# NameError: name 'filterDf' is not defined

# %%
#Ensures there exist at least 1 weather record for each day in the current month
dfDropna = filterDf
assert(len(dfDropna.Date.unique()) == 31)

# %%
dates = dfDropna.Date.unique()
for day in dates:
    dateDf = filterDf[filterDf["Date"] == day]
    dayWeather = test["Weather"].value_counts().idxmax()
    fillMissing = dateDf
    fillMissing["Weather"] = fillMissing["Weather"].replace(to_replace = np.nan, value = dayWeather)
# Out:
# array(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#        '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#        '2019-01-09', '2019-01-10', '2019-01-11', '2019-01-12',
#        '2019-01-13', '2019-01-14', '2019-01-15', '2019-01-16',
#        '2019-01-17', '2019-01-18', '2019-01-19', '2019-01-20',
#        '2019-01-21', '2019-01-22', '2019-01-23', '2019-01-24',
#        '2019-01-25', '2019-01-26', '2019-01-27', '2019-01-28',
#        '2019-01-29', '2019-01-30', '2019-01-31'], dtype=object)

# %%
test = dfDropna[dfDropna["Date"] == "2019-01-01"]
test
# Out:
#              Date/Time  Year  Month  Day   Time        Weather        Date
# 0  2019-01-01 00:00:00  2019      1    1  00:00            NaN  2019-01-01
# 1  2019-01-01 01:00:00  2019      1    1  01:00  Mostly Cloudy  2019-01-01
# 2  2019-01-01 02:00:00  2019      1    1  02:00            NaN  2019-01-01
# 3  2019-01-01 03:00:00  2019      1    1  03:00            NaN  2019-01-01
# 4  2019-01-01 04:00:00  2019      1    1  04:00         Cloudy  2019-01-01
# 5  2019-01-01 05:00:00  2019      1    1  05:00            NaN  2019-01-01
# 6  2019-01-01 06:00:00  2019      1    1  06:00            NaN  2019-01-01
# 7  2019-01-01 07:00:00  2019      1    1  07:00         Cloudy  2019-01-01
# 8  2019-01-01 08:00:00  2019      1    1  08:00            NaN  2019-01-01
# 9  2019-01-01 09:00:00  2019      1    1  09:00            NaN  2019-01-01
# 10 2019-01-01 10:00:00  2019      1    1  10:00         Cloudy  2019-01-01
# 11 2019-01-01 11:00:00  2019      1    1  11:00            NaN  2019-01-01
# 12 2019-01-01 12:00:00  2019      1    1  12:00            NaN  2019-01-01
