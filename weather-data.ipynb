# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("en_climate_daily_BC_1108395_2019_P1D.csv")
data
# Out:
#      Longitude (x)  Latitude (y)      Station Name  Climate ID   Date/Time  \
# 0          -123.18         49.19  VANCOUVER INTL A     1108395  2019-01-01
# 1          -123.18         49.19  VANCOUVER INTL A     1108395  2019-01-02
# 2          -123.18         49.19  VANCOUVER INTL A     1108395  2019-01-03
# 3          -123.18         49.19  VANCOUVER INTL A     1108395  2019-01-04
# 4          -123.18         49.19  VANCOUVER INTL A     1108395  2019-01-05
# ..             ...           ...               ...         ...         ...
# 360        -123.18         49.19  VANCOUVER INTL A     1108395  2019-12-27
# 361        -123.18         49.19  VANCOUVER INTL A     1108395  2019-12-28
# 362        -123.18         49.19  VANCOUVER INTL A     1108395  2019-12-29
# 363        -123.18         49.19  VANCOUVER INTL A     1108395  2019-12-30
# 364        -123.18         49.19  VANCOUVER INTL A     1108395  2019-12-31
#
#      Year  Month  Day  Data Quality  Max Temp (°C)  ... Total Snow (cm)  \
# 0    2019      1    1           NaN            5.3  ...             0.0
# 1    2019      1    2           NaN            5.5  ...             0.0
# 2    2019      1    3           NaN            9.5  ...             0.0
# 3    2019      1    4           NaN           10.4  ...             0.0
# 4    2019      1    5           NaN            8.7  ...             0.0
# ..    ...    ...  ...           ...            ...  ...             ...
# 360  2019     12   27           NaN            NaN  ...             NaN
# 361  2019     12   28           NaN            NaN  ...             NaN
# 362  2019     12   29           NaN            NaN  ...             NaN
# 363  2019     12   30           NaN            NaN  ...             NaN
# 364  2019     12   31           NaN            NaN  ...             NaN
#
#      Total Snow Flag Total Precip (mm)  Total Precip Flag Snow on Grnd (cm)  \
# 0                NaN               0.0                NaN               NaN
# 1                  T               3.4                NaN               NaN
# 2                NaN              54.8                NaN               NaN
# 3                NaN               9.6                NaN               NaN
# 4                NaN               3.2                NaN               NaN
# ..               ...               ...                ...               ...
# 360              NaN               NaN                NaN               NaN
# 361              NaN               NaN                NaN               NaN
# 362              NaN               NaN                NaN               NaN
# 363              NaN               NaN                NaN               NaN
# 364              NaN               NaN                NaN               NaN
#
#      Snow on Grnd Flag Dir of Max Gust (10s deg)  Dir of Max Gust Flag  \
# 0                  NaN                       NaN                     M
# 1                  NaN                       6.0                   NaN
# 2                  NaN                      14.0                   NaN
# 3                  NaN                      15.0                   NaN
# 4                  NaN                      10.0                   NaN
# ..                 ...                       ...                   ...
# 360                NaN                       NaN                   NaN
# 361                NaN                       NaN                   NaN
# 362                NaN                       NaN                   NaN
# 363                NaN                       NaN                   NaN
# 364                NaN                       NaN                   NaN
#
#     Spd of Max Gust (km/h)  Spd of Max Gust Flag
# 0                      NaN                     M
# 1                     41.0                   NaN
# 2                     54.0                   NaN
# 3                     45.0                   NaN
# 4                     33.0                   NaN
# ..                     ...                   ...
# 360                    NaN                   NaN
# 361                    NaN                   NaN
# 362                    NaN                   NaN
# 363                    NaN                   NaN
# 364                    NaN                   NaN
#
# [365 rows x 31 columns]

# %%
wget --content-disposition "https://climate.weather.gc.ca/climate_data/bulk_data_e.html?format=csv&stationID=51442&Year=2013&Month=12&Day=14&timeframe=2&submit= Download+Data"

# %%
data2 = pd.read_excel("clean-bike-theft.xlsx")
data2
# Out:
#      Occurred_Date_From ReformattedTime            DateTime  \
# 0            2008-01-01        00:00:00 2008-01-01 00:00:00
# 1            2008-01-01        00:00:00 2008-01-01 00:00:00
# 2            2008-01-01        12:00:00 2008-01-01 12:00:00
# 3            2008-01-04        18:00:00 2008-01-04 18:00:00
# 4            2008-01-06        08:00:00 2008-01-06 08:00:00
# ...                 ...             ...                 ...
# 7838         2012-12-28        02:00:00 2012-12-28 02:00:00
# 7839         2012-12-29        21:00:00 2012-12-29 21:00:00
# 7840         2012-12-30        10:32:00 2012-12-30 10:32:00
# 7841         2012-12-30        22:30:00 2012-12-30 22:30:00
# 7842         2012-12-31        18:45:00 2012-12-31 18:45:00
#
#       Occurred_Time_From                Description  district  Weekday  \
# 0                      0  THEFT BICYCLE UNDER $5000       4.0        3
# 1                      0  THEFT BICYCLE UNDER $5000       4.0        3
# 2                   1200  THEFT BICYCLE UNDER $5000       4.0        3
# 3                   1800  THEFT BICYCLE UNDER $5000       4.0        6
# 4                    800  THEFT BICYCLE UNDER $5000       1.0        1
# ...                  ...                        ...       ...      ...
# 7838                 200  THEFT BICYCLE UNDER $5000       1.0        6
# 7839                2100  THEFT BICYCLE UNDER $5000       3.0        7
# 7840                1032  THEFT BICYCLE UNDER $5000       3.0        1
# 7841                2230  THEFT BICYCLE UNDER $5000       4.0        1
# 7842                1845   THEFT BICYCLE OVER $5000       3.0        2
#
#          Month  Year               100 Block   100 Block CLEANED  \
# 0      January  2008        600 W 7TH AVE          600 W 7TH AVE
# 1      January  2008        700 W 7TH AVE          700 W 7TH AVE
# 2      January  2008        3500 MAIN ST            3500 MAIN ST
# 3      January  2008       3200 W 3RD AVE         3200 W 3RD AVE
# 4      January  2008    1000 W GEORGIA ST      1000 W GEORGIA ST
# ...        ...   ...                     ...                 ...
# 7838  December  2012    800 BROUGHTON ST        800 BROUGHTON ST
# 7839  December  2012       4700 MANOR ST           4700 MANOR ST
# 7840  December  2012        300 E 6TH AVE          300 E 6TH AVE
# 7841  December  2012       300 E 20TH AVE         300 E 20TH AVE
# 7842  December  2012  3600 COMMERCIAL ST      3600 COMMERCIAL ST
#
#      AddressConsolidated        Lat     Long
# 0          600 W 7TH AVE  49.265008 -123.118
# 1          700 W 7TH AVE  49.265040  -123.12
# 2           3500 MAIN ST  49.253888 -123.101
# 3         3200 W 3RD AVE  49.269359 -123.176
# 4      1000 W GEORGIA ST  49.284481 -123.121
# ...                  ...        ...      ...
# 7838    800 BROUGHTON ST  49.287907  -123.13
# 7839       4700 MANOR ST  49.242700 -123.039
# 7840       300 E 6TH AVE  49.265460 -123.099
# 7841      300 E 20TH AVE  49.252937 -123.099
# 7842  3600 COMMERCIAL ST  49.252555 -123.068
#
# [7843 rows x 14 columns]
